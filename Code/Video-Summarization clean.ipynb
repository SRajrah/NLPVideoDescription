# %%
import cv2
import os
import numpy as np

from transformers import BlipProcessor, BlipForConditionalGeneration
# from fairseq.models.ofa import OFATokenizer, OFAModel
from PIL import Image
import os
import torch

# %%
# Base path for the project
base_path = '/Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos'

# Change the video number and name dynamically
video_number = 'Video-02' 
video_name = 'First Flying Lesson _ Harry Potter and the Sorcerer s Stone.mp4'  # Set the video name

# %%
# Function to extract frames from a video
def extract_frames(video_path, output_folder, interval=1):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print("Error opening video file")
        return

    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        # Save the frame at the specified interval
        if frame_count % interval == 0:
            frame_filename = os.path.join(output_folder, f"frame_{frame_count}.jpg")
            cv2.imwrite(frame_filename, frame)
        
        frame_count += 1

    # Release the video capture object
    cap.release()
    print(f"Extracted {frame_count} frames.")

# %%
# video_path = '/Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos/Video-02/First Flying Lesson _ Harry Potter and the Sorcerer s Stone.mp4'  # Replace with your video path
video_path = f'{base_path}/{video_number}/{video_name}'
# output_folder = '/Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos/Video-02/Frames'  # Folder to save frames
output_folder = f'{base_path}/{video_number}/Frames'
interval = 10  # Save every 10th frame
extract_frames(video_path, output_folder, interval)
# Out:
# Extracted 7466 frames.

# %%
# Function to extract keyframes from the extracted frames with frame sampling
def extract_keyframes(frames_folder, keyframes_output_folder, threshold=100, sampling_interval=5):
    # Create output folder if it doesn't exist
    if not os.path.exists(keyframes_output_folder):
        os.makedirs(keyframes_output_folder)

    # List all frames in the frames folder
    frame_filenames = sorted(os.listdir(frames_folder), key=lambda x: int(x.split('_')[1].split('.')[0]))

    prev_frame = None
    keyframe_count = 0

    for idx, frame_filename in enumerate(frame_filenames):
        # Process only every nth frame
        if idx % sampling_interval != 0:
            continue

        frame_path = os.path.join(frames_folder, frame_filename)
        curr_frame = cv2.imread(frame_path)

        if prev_frame is None:
            prev_frame = curr_frame
            continue

        # Calculate the absolute difference between the current and previous frame
        frame_diff = cv2.absdiff(prev_frame, curr_frame)
        gray_diff = cv2.cvtColor(frame_diff, cv2.COLOR_BGR2GRAY)

        # Threshold the difference to get a binary image
        _, thresh = cv2.threshold(gray_diff, 30, 255, cv2.THRESH_BINARY)

        # Count the number of non-zero pixels in the thresholded image
        non_zero_count = cv2.countNonZero(thresh)

        # If the number of different pixels exceeds the threshold, save the frame as a keyframe
        if non_zero_count > threshold:
            keyframe_filename = os.path.join(keyframes_output_folder, f"keyframe_{keyframe_count}.jpg")
            cv2.imwrite(keyframe_filename, curr_frame)
            keyframe_count += 1

        prev_frame = curr_frame

    print(f"Extracted {keyframe_count} keyframes.")

# %%
# frames_folder = '/Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos/Video-02/Frames'  # Folder with extracted frames
frames_folder = f'{base_path}/{video_number}/Frames'  # Folder with extracted frames
# keyframes_output_folder = '/Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos/Video-02/Key-frames'  # Folder to save keyframes
keyframes_output_folder = f'{base_path}/{video_number}/Key-frames'
extract_keyframes(frames_folder, keyframes_output_folder, threshold=100, sampling_interval=5)
# Out:
# Extracted 149 keyframes.

# %%
# Function to extract keyframes using optical flow
def extract_keyframes_optical_flow(frames_folder, keyframes_output_folder, flow_threshold=0.5, sampling_interval=5):
    # Create output folder if it doesn't exist
    if not os.path.exists(keyframes_output_folder):
        os.makedirs(keyframes_output_folder)

    # List all frames in the frames folder
    frame_filenames = sorted(os.listdir(frames_folder), key=lambda x: int(x.split('_')[1].split('.')[0]))

    prev_frame_gray = None
    keyframe_count = 0

    for idx, frame_filename in enumerate(frame_filenames):
        # Process only every nth frame
        if idx % sampling_interval != 0:
            continue

        frame_path = os.path.join(frames_folder, frame_filename)
        curr_frame = cv2.imread(frame_path)

        # Convert the current frame to grayscale for optical flow calculation
        curr_frame_gray = cv2.cvtColor(curr_frame, cv2.COLOR_BGR2GRAY)

        # If this is the first frame, skip optical flow calculation
        if prev_frame_gray is None:
            prev_frame_gray = curr_frame_gray
            continue

        # Calculate dense optical flow using the Farneback method
        flow = cv2.calcOpticalFlowFarneback(prev_frame_gray, curr_frame_gray, None, 
                                            0.5, 3, 15, 3, 5, 1.2, 0)

        # Compute the magnitude and angle of 2D vectors
        magnitude, _ = cv2.cartToPolar(flow[..., 0], flow[..., 1])

        # Calculate the mean motion magnitude
        mean_magnitude = np.mean(magnitude)

        # If the mean motion exceeds the threshold, save the frame as a keyframe
        if mean_magnitude > flow_threshold:
            keyframe_filename = os.path.join(keyframes_output_folder, f"keyframe_{keyframe_count}.jpg")
            cv2.imwrite(keyframe_filename, curr_frame)
            keyframe_count += 1

        prev_frame_gray = curr_frame_gray

    print(f"Extracted {keyframe_count} keyframes using optical flow.")

# %%
# frames_folder = '/Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos/Video-02/Frames'  # Folder with extracted frames
frames_folder = f'{base_path}/{video_number}/Frames'
# keyframes_output_folder = '/Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos/Video-02/Key-frames'  # Folder to save keyframes
keyframes_output_folder = f'{base_path}/{video_number}/Key-frames'
extract_keyframes_optical_flow(frames_folder, keyframes_output_folder, flow_threshold=0.5, sampling_interval=5)
# Out:
# Extracted 149 keyframes using optical flow.

# %%
# Initialize BLIP model and processor
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# Function to generate descriptions for all keyframes
def generate_keyframe_descriptions(keyframes_folder, descriptions_output_file):
    # List all keyframes in the keyframes folder
    keyframe_filenames = sorted(os.listdir(keyframes_folder), key=lambda x: int(x.split('_')[1].split('.')[0]))

    descriptions = {}  # To store keyframe descriptions

    for keyframe_filename in keyframe_filenames:
        keyframe_path = os.path.join(keyframes_folder, keyframe_filename)
        image = Image.open(keyframe_path)

        # Preprocess and generate caption for the current keyframe
        inputs = processor(image, return_tensors="pt")
        out = model.generate(**inputs)

        # Decode the tokenized output to get the caption
        caption = processor.decode(out[0], skip_special_tokens=True)
        descriptions[keyframe_filename] = caption
        print(f"Generated Caption for {keyframe_filename}: {caption}")

    # Save descriptions to a file for later use
    with open(descriptions_output_file, 'w') as f:
        for keyframe_filename, caption in descriptions.items():
            f.write(f"{keyframe_filename}: {caption}\n")

    print(f"Descriptions for {len(keyframe_filenames)} keyframes saved to {descriptions_output_file}")
# Out:
# /Users/adwaitmahadar/.pyenv/versions/3.12.2/envs/NLP-Project/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# Paths for keyframes and output descriptions file
# keyframes_folder = '/Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos/Video-02/Key-frames'  # Folder where keyframes are saved
keyframes_folder = f'{base_path}/{video_number}/Key-frames'
# descriptions_output_file = '/Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos/Video-02/Descriptions/descriptions_blip.txt'  # File to save the descriptions
descriptions_output_file = f'{base_path}/{video_number}/Descriptions/descriptions_blip.txt'

# Generate descriptions for all keyframes
generate_keyframe_descriptions(keyframes_folder, descriptions_output_file)
# Out:
# /Users/adwaitmahadar/.pyenv/versions/3.12.2/envs/NLP-Project/lib/python3.12/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Generated Caption for keyframe_0.jpg: a group of people standing in a field
# Generated Caption for keyframe_1.jpg: a group of people standing in a circle
# Generated Caption for keyframe_2.jpg: a group of people in a field with a shadow
# Generated Caption for keyframe_3.jpg: a group of people standing in a field
# Generated Caption for keyframe_4.jpg: a group of people standing around a tree
# Generated Caption for keyframe_5.jpg: harry and hermik in the harry ' s house
# Generated Caption for keyframe_6.jpg: harry and hermik in the dark knight
# Generated Caption for keyframe_7.jpg: a man with grey hair and a suit
# Generated Caption for keyframe_8.jpg: a woman with a surprised look on her face
# Generated Caption for keyframe_9.jpg: a woman with a suit and tie is making a face
# Generated Caption for keyframe_10.jpg: a woman in a black coat standing in front of a stone wall
# Generated Caption for keyframe_11.jpg: harry and hermik in the harry ' s house
# Generated Caption for keyframe_12.jpg: harry and his family walk through the grounds
# Generated Caption for keyframe_13.jpg: a group of people standing in front of a castle
# Generated Caption for keyframe_14.jpg: a woman in a black coat holding a dog
# Generated Caption for keyframe_15.jpg: harry potter ' s school of witchcraft
# Generated Caption for keyframe_16.jpg: two young children dressed in harry potter costumes
# Generated Caption for keyframe_17.jpg: harry potter in harry potter potter potter potter potter potter potter potter potter potter potter potter potter potter potter
# Generated Caption for keyframe_18.jpg: two young boys are standing in front of a white wall
# Generated Caption for keyframe_19.jpg: a group of young boys standing next to each other boys
# Generated Caption for keyframe_20.jpg: harry and his brother
# Generated Caption for keyframe_21.jpg: a man in a black coat and a brown dog
# Generated Caption for keyframe_22.jpg: harry and hermik in the making of harry ' s house
# Generated Caption for keyframe_23.jpg: two young girls singing in front of a brick wall
# Generated Caption for keyframe_24.jpg: a person holding a baseball bat in the grass
# Generated Caption for keyframe_25.jpg: two young girls in harry costumes standing next to each other girls
# Generated Caption for keyframe_26.jpg: a young boy in a school uniform is standing in front of a brick wall
# Generated Caption for keyframe_27.jpg: harry and hermik ' s harry potter wedding
# Generated Caption for keyframe_28.jpg: harry potters in the harry potters
# Generated Caption for keyframe_29.jpg: a man and woman walking in a field
# Generated Caption for keyframe_30.jpg: harry and the chamber of death
# Generated Caption for keyframe_31.jpg: harry potters in harry potters
# Generated Caption for keyframe_32.jpg: harry potter and hermilan
# Generated Caption for keyframe_33.jpg: harry potters in the middle of a group of people
# Generated Caption for keyframe_34.jpg: harry potters in the middle of a group of people
# Generated Caption for keyframe_35.jpg: harry ' s school - official trailer
# Generated Caption for keyframe_36.jpg: a man in a coat and tie standing in front of a castle
# Generated Caption for keyframe_37.jpg: a man in a black jacket standing in front of a castle
# Generated Caption for keyframe_38.jpg: a man with a black jacket and white shirt
# Generated Caption for keyframe_39.jpg: a group of children standing in front of a building
# Generated Caption for keyframe_40.jpg: a group of people standing around a building
# Generated Caption for keyframe_41.jpg: harry and his friends are walking in the street
# Generated Caption for keyframe_42.jpg: a young boy in a black robe and a young girl in a black robe
# Generated Caption for keyframe_43.jpg: a young boy in a black suit and tie standing next to a woman
# Generated Caption for keyframe_44.jpg: a group of people standing around a building
# Generated Caption for keyframe_45.jpg: a person in black boots standing on grass
# Generated Caption for keyframe_46.jpg: a young boy in a black coat and tie
# Generated Caption for keyframe_47.jpg: a group of people in robes and robes playing instruments
# Generated Caption for keyframe_48.jpg: harry and his staffs
# Generated Caption for keyframe_49.jpg: a man in a suit playing a guitar
# Generated Caption for keyframe_50.jpg: a woman with grey hair and a baseball bat
# Generated Caption for keyframe_51.jpg: a man holding a wooden stick in front of a castle
# Generated Caption for keyframe_52.jpg: a group of young people standing next to each other people
# Generated Caption for keyframe_53.jpg: a group of people in black robes dancing
# Generated Caption for keyframe_54.jpg: a man standing in front of a group of men
# Generated Caption for keyframe_55.jpg: a woman with blonde hair and a suit
# Generated Caption for keyframe_56.jpg: a man is holding a guitar in the air
# Generated Caption for keyframe_57.jpg: a blur of a person walking on a sidewalk
# Generated Caption for keyframe_58.jpg: a man is jumping over a wall
# Generated Caption for keyframe_59.jpg: a man in a black shirt is standing on a wall
# Generated Caption for keyframe_60.jpg: a view of the mountains from a castle
# Generated Caption for keyframe_61.jpg: a bird is flying over a green field
# Generated Caption for keyframe_62.jpg: a man in a harry costume is holding a wand
# Generated Caption for keyframe_63.jpg: a group of people in black robes and holding swords
# Generated Caption for keyframe_64.jpg: a view through a tunnel into a castle
# Generated Caption for keyframe_65.jpg: a bird flying through a narrow gap in a cliff
# Generated Caption for keyframe_66.jpg: a man standing on top of a castle
# Generated Caption for keyframe_67.jpg: a man is flying through the air with a pole
# Generated Caption for keyframe_68.jpg: a group of people standing on a sidewalk
# Generated Caption for keyframe_69.jpg: a group of people are gathered around a building
# Generated Caption for keyframe_70.jpg: a young boy is standing on a rock
# Generated Caption for keyframe_71.jpg: a black flag flying in the sky
# Generated Caption for keyframe_72.jpg: a man is hanging from a building
# Generated Caption for keyframe_73.jpg: a group of people in black robes standing in front of a stone wall
# Generated Caption for keyframe_74.jpg: a group of people in black robes walking down a sidewalk
# Generated Caption for keyframe_75.jpg: nuns walking down the street
# Generated Caption for keyframe_76.jpg: two men in robes are walking down the street
# Generated Caption for keyframe_77.jpg: a man kneeling in front of a stone wall
# Generated Caption for keyframe_78.jpg: a group of young children standing next to each other children
# Generated Caption for keyframe_79.jpg: a man and a woman sitting on a bench
# Generated Caption for keyframe_80.jpg: a man and a boy are sitting on a bench
# Generated Caption for keyframe_81.jpg: three men in robes holding a stick and a stick
# Generated Caption for keyframe_82.jpg: a person is bending their foot in the grass
# Generated Caption for keyframe_83.jpg: a stone wall with a green grass field in the background
# Generated Caption for keyframe_84.jpg: a woman and a boy standing next to each other people
# Generated Caption for keyframe_85.jpg: a boy and a girl standing next to each other boy
# Generated Caption for keyframe_86.jpg: a boy and a girl standing next to each other boy
# Generated Caption for keyframe_87.jpg: a boy and a boy are standing in front of a stone wall
# Generated Caption for keyframe_88.jpg: a boy and a girl are eating food
# Generated Caption for keyframe_89.jpg: harry and hermik in the wizard ' s lair
# Generated Caption for keyframe_90.jpg: a group of children standing around a man in a suit
# Generated Caption for keyframe_91.jpg: a group of people standing around a group of people
# Generated Caption for keyframe_92.jpg: harry and his friends are gathered around the altar
# Generated Caption for keyframe_93.jpg: a group of young people dressed in black robes
# Generated Caption for keyframe_94.jpg: harry and his friends are in the middle school
# Generated Caption for keyframe_95.jpg: harry and hermik in harry ' s school
# Generated Caption for keyframe_96.jpg: harry and the chamber of death
# Generated Caption for keyframe_97.jpg: harry and hermik in the harry ' s school
# Generated Caption for keyframe_98.jpg: a young boy in a suit and tie is holding a bat
# Generated Caption for keyframe_99.jpg: a young boy in a suit and tie is looking at another
# Generated Caption for keyframe_100.jpg: a young boy in a suit and tie holding a stick
# Generated Caption for keyframe_101.jpg: harry potter and hermilan
# Generated Caption for keyframe_102.jpg: harry potter and hermilan
# Generated Caption for keyframe_103.jpg: harry potters and hermik potters
# Generated Caption for keyframe_104.jpg: harry potters and hermik potters
# Generated Caption for keyframe_105.jpg: a man in a suit is walking across a field
# Generated Caption for keyframe_106.jpg: a man in a suit is walking down a path
# Generated Caption for keyframe_107.jpg: a woman with blonde hair standing in front of a building
# Generated Caption for keyframe_108.jpg: a group of young people in a field
# Generated Caption for keyframe_109.jpg: a young girl holding a stick in front of a group of people
# Generated Caption for keyframe_110.jpg: harry and hermik in the harry ' s house
# Generated Caption for keyframe_111.jpg: harry and hermik in harry ' s house
# Generated Caption for keyframe_112.jpg: harry and his friends are all dressed up for the harry ' s school
# Generated Caption for keyframe_113.jpg: a group of young people standing in front of a building
# Generated Caption for keyframe_114.jpg: harry and hermik in harry ' s house
# Generated Caption for keyframe_115.jpg: a young boy is standing in front of a group of people
# Generated Caption for keyframe_116.jpg: a woman in a suit is standing next to a man
# Generated Caption for keyframe_117.jpg: a woman in a black suit and a man in a suit
# Generated Caption for keyframe_118.jpg: harry potter and hermilan
# Generated Caption for keyframe_119.jpg: a man in a suit standing next to a woman
# Generated Caption for keyframe_120.jpg: a man standing on top of a mountain
# Generated Caption for keyframe_121.jpg: a man in a suit and tie standing on a hill
# Generated Caption for keyframe_122.jpg: a woman with blonde hair holding a magni
# Generated Caption for keyframe_123.jpg: harry potter in the harry potters
# Generated Caption for keyframe_124.jpg: a woman standing in front of a forest
# Generated Caption for keyframe_125.jpg: a man in a suit standing on top of a mountain
# Generated Caption for keyframe_126.jpg: a plane flying through the sky with a small object in the sky
# Generated Caption for keyframe_127.jpg: a man in a black coat
# Generated Caption for keyframe_128.jpg: a castle with a tower and a clock
# Generated Caption for keyframe_129.jpg: a woman sitting at a desk in front of a window
# Generated Caption for keyframe_130.jpg: harry ' s desk in the harry ' s house
# Generated Caption for keyframe_131.jpg: a man in a suit holding a bat
# Generated Caption for keyframe_132.jpg: a woman in a black coat is sitting on a bench
# Generated Caption for keyframe_133.jpg: a man in a suit is eating something
# Generated Caption for keyframe_134.jpg: a woman looking through a window at something
# Generated Caption for keyframe_135.jpg: a woman looking through a window at something
# Generated Caption for keyframe_136.jpg: a woman is standing in front of a castle
# Generated Caption for keyframe_137.jpg: a person taking a picture of a castle
# Generated Caption for keyframe_138.jpg: a man in a black coat is taking a picture
# Generated Caption for keyframe_139.jpg: a group of young children in school uniforms
# Generated Caption for keyframe_140.jpg: a woman in a black dress is standing on a brick path
# Generated Caption for keyframe_141.jpg: a woman in a black dress is dancing
# Generated Caption for keyframe_142.jpg: harry and his friends are walking in the grass
# Generated Caption for keyframe_143.jpg: a group of children standing in front of a building
# Generated Caption for keyframe_144.jpg: a man in a green coat and black pants
# Generated Caption for keyframe_145.jpg: a man in a green coat and black shirt
# Generated Caption for keyframe_146.jpg: harry and hermik in the harry potters
# Generated Caption for keyframe_147.jpg: a woman in a green jacket and black shirt
# Generated Caption for keyframe_148.jpg: a woman in a green dress standing in front of a crowd
# Descriptions for 149 keyframes saved to /Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos/Video-02/Descriptions/descriptions_blip.txt

# %%
# Initialize BLIP-2 model and processor
# processor = BlipProcessor.from_pretrained("Salesforce/blip2-image-captioning")
# model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip2-image-captioning")

# # Function to generate descriptions for all keyframes using BLIP-2
# def generate_keyframe_descriptions_blip2(keyframes_folder, descriptions_output_file):
#     # List all keyframes in the keyframes folder
#     keyframe_filenames = sorted(os.listdir(keyframes_folder), key=lambda x: int(x.split('_')[1].split('.')[0]))

#     descriptions = {}  # To store keyframe descriptions

#     for keyframe_filename in keyframe_filenames:
#         keyframe_path = os.path.join(keyframes_folder, keyframe_filename)
#         image = Image.open(keyframe_path)

#         # Preprocess and generate caption for the current keyframe using BLIP-2
#         inputs = processor(images=image, return_tensors="pt")
#         out = model.generate(**inputs)

#         # Decode the tokenized output to get the caption
#         caption = processor.decode(out[0], skip_special_tokens=True)
#         descriptions[keyframe_filename] = caption
#         print(f"Generated Caption for {keyframe_filename}: {caption}")

#     # Save descriptions to a file for later use
#     with open(descriptions_output_file, 'w') as f:
#         for keyframe_filename, caption in descriptions.items():
#             f.write(f"{keyframe_filename}: {caption}\n")

#     print(f"Descriptions for {len(keyframe_filenames)} keyframes saved to {descriptions_output_file}")

# %%
# # Paths for keyframes and output descriptions file
# # keyframes_folder = '/Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos/Video-02/Key-frames'  # Folder where keyframes are saved
# keyframes_folder = f'{base_path}/{video_number}/Key-frames'
# # descriptions_output_file = '/Users/adwaitmahadar/Disk-1/MSCS/Fall-24/CSCI-544/Project/Videos/Video-02/Descriptions/descriptions_blip2.txt'  # File to save the descriptions
# descriptions_output_file = f'{base_path}/{video_number}/Descriptions/descriptions_blip2.txt'

# # Generate descriptions for all keyframes using BLIP-2
# generate_keyframe_descriptions_blip2(keyframes_folder, descriptions_output_file)

# %%
# # Initialize OFA model and tokenizer
# tokenizer = OFATokenizer.from_pretrained("OFA-Sys/OFA-base")
# model = OFAModel.from_pretrained("OFA-Sys/OFA-base")
# model.eval()  # Set model to evaluation mode

# %%
# # Function to preprocess images and tokenize inputs for OFA model
# def preprocess_image(image):
#     image = image.convert("RGB")
#     return image

# %%
# # Function to generate descriptions for all keyframes using OFA
# def generate_keyframe_descriptions_ofa(keyframes_folder, descriptions_output_file):
#     # List all keyframes in the keyframes folder
#     keyframe_filenames = sorted(os.listdir(keyframes_folder), key=lambda x: int(x.split('_')[1].split('.')[0]))

#     descriptions = {}  # To store keyframe descriptions

#     for keyframe_filename in keyframe_filenames:
#         keyframe_path = os.path.join(keyframes_folder, keyframe_filename)
#         image = Image.open(keyframe_path)

#         # Preprocess the image for OFA
#         image = preprocess_image(image)

#         # Tokenize the input
#         inputs = tokenizer(image, return_tensors="pt", padding=True)

#         # Generate the caption
#         with torch.no_grad():
#             outputs = model.generate(inputs["input_ids"])

#         # Decode the tokenized output to get the caption
#         caption = tokenizer.decode(outputs[0], skip_special_tokens=True)
#         descriptions[keyframe_filename] = caption
#         print(f"Generated Caption for {keyframe_filename}: {caption}")

#     # Save descriptions to a file for later use
#     with open(descriptions_output_file, 'w') as f:
#         for keyframe_filename, caption in descriptions.items():
#             f.write(f"{keyframe_filename}: {caption}\n")

#     print(f"Descriptions for {len(keyframe_filenames)} keyframes saved to {descriptions_output_file}")
